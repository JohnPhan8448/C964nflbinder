# %%
import warnings
warnings.filterwarnings('ignore')

import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
#!jupyter nbextension enable --py widgetsnbextension --sys-prefix
#!jupyter serverextension enable voila --sys-prefix

# %%
#load the data sets
trainingDF = pd.read_csv('2018_2021_cleaned.csv')
trainingDF
gameDF = pd.read_csv('2022_cleaned.csv')
gameDF
# Out:
#      Day       Date                  away  away_score  Tm_score  \
# 0    Thu   9/8/2022         Buffalo Bills        31.0      10.0
# 1    Sun  9/11/2022   Philadelphia Eagles        38.0      35.0
# 2    Sun  9/11/2022      Baltimore Ravens        24.0       9.0
# 3    Sun  9/11/2022   San Francisco 49ers        10.0      19.0
# 4    Sun  9/11/2022  New England Patriots         7.0      20.0
# ..   ...        ...                   ...         ...       ...
# 267  Sun   1/8/2023  New England Patriots         NaN       NaN
# 268  Sun   1/8/2023      Tennessee Titans         NaN       NaN
# 269  Sun   1/8/2023      Cleveland Browns         NaN       NaN
# 270  Sun   1/8/2023  Tampa Bay Buccaneers         NaN       NaN
# 271  Sun   1/8/2023        Dallas Cowboys         NaN       NaN
#
#                       Tm_x    won  result  W_x  L_x  ...  T_y  W-L%_y  PF_y  \
# 0         Los Angeles Rams  False       0    3    3  ...    0   0.833   176
# 1            Detroit Lions  False       0    1    4  ...    0   1.000   161
# 2            New York Jets  False       0    4    2  ...    0   0.500   158
# 3            Chicago Bears   True       1    2    4  ...    0   0.500   122
# 4           Miami Dolphins   True       1    3    3  ...    0   0.500   141
# ..                     ...    ...     ...  ...  ...  ...  ...     ...   ...
# 267          Buffalo Bills  False       0    5    1  ...    0   0.500   141
# 268   Jacksonville Jaguars  False       0    2    4  ...    0   0.600    96
# 269    Pittsburgh Steelers  False       0    2    4  ...    0   0.333   148
# 270        Atlanta Falcons  False       0    3    3  ...    0   0.500   121
# 271  Washington Commanders  False       0    2    4  ...    0   0.667   110
#
#      PA_y  PD_y  MoV_y  SoS_y  SRS_y  OSRS_y  DSRS_y
# 0      81    95   15.8    2.2   18.0     5.8    12.2
# 1     105    56    9.3   -1.1    8.2     4.0     4.2
# 2     141    17    2.8    6.3    9.2     9.4    -0.2
# 3      89    33    5.5   -4.6    0.9    -2.5     3.5
# 4     113    28    4.7    0.2    4.9    -2.5     7.4
# ..    ...   ...    ...    ...    ...     ...     ...
# 267   113    28    4.7    0.2    4.9    -2.5     7.4
# 268   118   -22   -4.4    1.8   -2.6     0.2    -2.8
# 269   163   -15   -2.5   -1.6   -4.1     3.0    -7.1
# 270   103    18    3.0    0.0    3.0    -3.9     6.9
# 271    98    12    2.0    1.7    3.7    -0.1     3.8
#
# [272 rows x 33 columns]
